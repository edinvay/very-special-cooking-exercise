# %%
# Written in Julia 1.9.2
# here you call the packages that you want to use
using Plots

# %%
# created an array of complex numbers
z = exp.(range(0, 2π, 65)im)
# plotting with a `plot` command
plot(z; title="Ellipse", legend=:bottomright, labels="z")
